# %% [markdown]
# ## Outer version

# %%
# -*- coding: utf-8 -*-
"""
IEOR4004 Project 1 — Part 2 solver (robust version)
Requirements: gurobipy, pandas, numpy
Place CSVs in same folder or update the file paths below.
"""

import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
from itertools import combinations
from pathlib import Path

# ------------------------------
# 1. Data Paths (edit if needed)
# ------------------------------


POP_FILE   = Path("Project 1 Data- version 0.0- Yue Chen/population_calculated.csv")
CLASS_FILE = Path("Project 1 Data- version 0.0- Yue Chen/demand_classification.csv")
FAC_FILE   = Path("Project 1 Data- version 0.0- Yue Chen/child_care_regulated_cleaned.csv")
SITE_FILE  = Path("Project 1 Data- version 0.0- Yue Chen/potential_locations.csv")

# ------------------------------
# 2. Global Parameters
# ------------------------------
BETA  = 100.0          # Equipment cost per 0–5 slot
DELTA = 0.06           # Minimum distance (miles) for conflict
Q05_IMPUTE_RATIO = 1 # Default ratio if q_0_5 missing

# ------------------------------
# 3. Default Facility Sizes
# ------------------------------
DEFAULT_SIZES = pd.DataFrame({
    "k": ["S", "M", "L"],
    "cap_k": [100, 200, 400],
    "cap_k_0_5": [50, 100, 200],
    "cost_k": [65000, 95000, 115000],
})

# %%
# ------------------------------
# 4. Helper functions
# ------------------------------
def pad_zip(z):
    """Ensure ZIP codes are five digits (e.g., 123 -> 00123)."""
    if pd.isna(z):
        return ""
    s = str(z).strip()
    if s.endswith(".0"):
        s = s[:-2]
    return s.zfill(5)

def haversine(lat1, lon1, lat2, lon2):
    """Compute great-circle distance (miles) between two (lat, lon) points."""
    if any(pd.isna(v) for v in (lat1, lon1, lat2, lon2)):
        return np.inf
    R = 3958.8  # Earth radius in miles
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    a = np.sin((lat2 - lat1) / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin((lon2 - lon1) / 2.0)**2
    return 2.0 * R * np.arcsin(np.sqrt(a))

# %%
# ------------------------------
# 5. Data Loading and cleaning
# ------------------------------
def load_data():
    """Load and preprocess population, classification, facilities, and site data."""
    # --- Load population ---
    pop = pd.read_csv(POP_FILE)
    pop["zip_code_cleaned"] = pop["zip_code_cleaned"].apply(pad_zip)
    pop.rename(columns={"Population_0_12": "pop_0_12", "Population_0_5": "pop_0_5"}, inplace=True)
    pop["pop_0_12"] = pd.to_numeric(pop.get("pop_0_12", 0), errors="coerce").fillna(0)
    pop["pop_0_5"]  = pd.to_numeric(pop.get("pop_0_5", 0), errors="coerce").fillna(0)

    # --- Load demand classification ---
    cls = pd.read_csv(CLASS_FILE)
    cls["zip_code_cleaned"] = cls["zip_code_cleaned"].apply(pad_zip)
    cls.rename(columns={"Demand_Classification": "class"}, inplace=True)
    cls["class"] = cls["class"].astype(str).str.strip().str.lower()
    cls["t_i"] = np.where(cls["class"].str.contains("high", na=False), 0.5, 1/3)

    # --- Outer join instead of intersection ---
    areas = pop.merge(
        cls[["zip_code_cleaned", "t_i"]],
        on="zip_code_cleaned",
        how="outer",
        validate="one_to_one"
    )

    # --- Fill missing data safely ---
    areas["pop_0_12"] = areas["pop_0_12"].fillna(0)
    areas["pop_0_5"] = areas["pop_0_5"].fillna(0)
    areas["t_i"] = areas["t_i"].fillna(1/3)

    # --- Enforce correct types ---
    areas["pop_0_12"] = areas["pop_0_12"].astype(float)
    areas["pop_0_5"] = areas["pop_0_5"].astype(float)
    areas["t_i"] = areas["t_i"].astype(float)

    print(f"[load_data] ZIP union: {len(areas)} total (pop={len(pop)}, cls={len(cls)})")

    # --- Facility data ---
    fac = pd.read_csv(FAC_FILE)
    fac["zip_code_cleaned"] = fac["zip_code_cleaned"].apply(pad_zip)
    if "total_capacity" in fac.columns:
        fac.rename(columns={"total_capacity": "n_f"}, inplace=True)
    if "latitude" in fac.columns:
        fac.rename(columns={"latitude": "lat"}, inplace=True)
    if "longitude" in fac.columns:
        fac.rename(columns={"longitude": "lon"}, inplace=True)

    # compute or impute q_0_5
    if "q_0_5" not in fac.columns:
        if all(col in fac.columns for col in ["infant_capacity", "toddler_capacity", "preschool_capacity"]):
            fac["q_0_5"] = fac["infant_capacity"].fillna(0) + fac["toddler_capacity"].fillna(0) + fac["preschool_capacity"].fillna(0)
        else:
            fac["n_f"] = pd.to_numeric(fac.get("n_f", 0), errors="coerce").fillna(0)
            fac["q_0_5"] = (fac["n_f"] * Q05_IMPUTE_RATIO).round(0)

    fac = fac[["facility_id", "zip_code_cleaned", "n_f", "q_0_5", "lat", "lon"]].copy()
    fac["n_f"] = pd.to_numeric(fac["n_f"], errors="coerce").fillna(0)
    fac["q_0_5"] = pd.to_numeric(fac["q_0_5"], errors="coerce").fillna(0)

    before_fac_count = len(fac)
    fac = fac[fac["n_f"] > 0].copy()
    after_fac_count = len(fac)

    # --- Site data ---
    site = pd.read_csv(SITE_FILE)
    site.rename(columns={"zipcode": "zip_code_cleaned", "latitude": "lat", "longitude": "lon"}, inplace=True)
    site["zip_code_cleaned"] = site["zip_code_cleaned"].apply(pad_zip)
    site["site_id"] = np.arange(1, len(site) + 1)
    site = site[["site_id", "zip_code_cleaned", "lat", "lon"]].copy()

    sizes = DEFAULT_SIZES.copy()

    # --- Drop known infeasible ZIPs ---
    drop_zips = ["11219"]
    areas = areas[~areas["zip_code_cleaned"].isin(drop_zips)].copy()
    print(f"[load_data] Dropped infeasible ZIPs: {drop_zips}")

    print(f"[load_data] areas: {len(areas)}, facilities (before filter): {before_fac_count}, (after filter): {after_fac_count}, sites: {len(site)}")
    print("[load_data] sample areas head:\n", areas.head().to_string(index=False))

    return areas, fac, site, sizes

# %%
# ------------------------------
# 6. Spatial feasibility and conflicts
# ------------------------------
def infer_sites(sites, facs, delta=DELTA):
    """Mark candidate sites as feasible (1) or infeasible (0) if within DELTA miles of existing facility."""
    sites = sites.copy()
    sites["allowed"] = 1
    if len(facs) == 0:
        sites["allowed"] = 1
        return sites
    for i, s in sites.iterrows():
        # check existing facilities in same zip first (faster)
        zf = facs[facs["zip_code_cleaned"] == s["zip_code_cleaned"]]
        infeasible = False
        for _, f in zf.iterrows():
            if haversine(s["lat"], s["lon"], f["lat"], f["lon"]) < delta:
                infeasible = True
                break
        sites.loc[i, "allowed"] = 0 if infeasible else 1
    return sites

def conflict_pairs(sites, delta=DELTA):
    """Find pairs of sites that are closer than delta miles (we restrict to sites within same zip for efficiency)."""
    pairs = []
    if len(sites) == 0:
        return pairs
    for zip_i, grp in sites.groupby("zip_code_cleaned"):
        idxs = list(grp.index)
        if len(idxs) < 2:
            continue
        for i, j in combinations(idxs, 2):
            if haversine(grp.loc[i, "lat"], grp.loc[i, "lon"], grp.loc[j, "lat"], grp.loc[j, "lon"]) < delta:
                pairs.append((grp.loc[i, "site_id"], grp.loc[j, "site_id"]))
    print(f"[conflict_pairs] conflict pairs found: {len(pairs)}")
    return pairs

# %%
# ------------------------------
# 7. Cost segments (protect divide-by-zero)
# ------------------------------
def cost_segments(n):
    """Return unit costs for three expansion segments based on current capacity n.
       If n is <= 0, return very large unit costs (should have been filtered out earlier)."""
    if n <= 0 or pd.isna(n):
        # safe fallback: very large per-slot cost to discourage selecting this facility
        large = 1e6
        return (large, large, large)
    return ((20000 + 200.0 * n) / n,
            (20000 + 400.0 * n) / n,
            (20000 + 1000.0 * n) / n)

# %%
# ------------------------------
# 8. Build model
# ------------------------------
def build_model(areas, facs, sites, sizes, pairs, time_limit=120, mip_gap=0.01):
    """Create Gurobi model following the problem formulation (robust to empty sets)."""
    I = list(areas["zip_code_cleaned"])
    F = list(facs["facility_id"])
    S = list(sites["site_id"])
    K = list(sizes["k"])

    # parameter maps (use dict.get with default to avoid KeyError)
    nf   = dict(zip(facs.facility_id, facs.n_f))
    q05  = dict(zip(facs.facility_id, facs.q_0_5))
    zip_f = dict(zip(facs.facility_id, facs.zip_code_cleaned))
    zip_s = dict(zip(sites.site_id, sites.zip_code_cleaned))
    ti   = dict(zip(areas.zip_code_cleaned, areas.t_i))
    Pi   = dict(zip(areas.zip_code_cleaned, areas.pop_0_12))
    Pi05 = dict(zip(areas.zip_code_cleaned, areas.pop_0_5))
    cap  = dict(zip(sizes.k, sizes.cap_k))
    cap05= dict(zip(sizes.k, sizes.cap_k_0_5))
    cost = dict(zip(sizes.k, sizes.cost_k))
    allow= dict(zip(sites.site_id, sites.allowed if "allowed" in sites.columns else [1]*len(sites)))

    # segment unit costs
    c1 = {f: cost_segments(nf.get(f, 0))[0] for f in F}
    c2 = {f: cost_segments(nf.get(f, 0))[1] for f in F}
    c3 = {f: cost_segments(nf.get(f, 0))[2] for f in F}

    # create model
    m = gp.Model("IEOR4004_Project1_Part2_Gurobi")
    m.Params.OutputFlag = 1
    m.setParam("MIPGap", mip_gap)
    m.setParam("TimeLimit", time_limit)

    # variables: handle empty sets gracefully
    x1 = m.addVars(F, vtype=GRB.CONTINUOUS, name="x_f1") if F else {}
    x2 = m.addVars(F, vtype=GRB.CONTINUOUS, name="x_f2") if F else {}
    x3 = m.addVars(F, vtype=GRB.CONTINUOUS, name="x_f3") if F else {}
    # all y's are continuous in [0,1] (continuous piecewise expansion)
    y1 = m.addVars(F, lb=0, ub=1, name="y_f1") if F else {}
    y2 = m.addVars(F, lb=0, ub=1, name="y_f2") if F else {}
    y3 = m.addVars(F, lb=0, ub=1, name="y_f3") if F else {}
    # removed binary b2, b3
    xF = m.addVars(F, vtype=GRB.CONTINUOUS, name="x_f") if F else {}
    z05 = m.addVars(F, vtype=GRB.CONTINUOUS, name="z_f05") if F else {}

    y_sk   = m.addVars(S, K, vtype=GRB.BINARY, name="y_sk") if S and K else {}
    u_sk05 = m.addVars(S, K, vtype=GRB.CONTINUOUS, name="u_sk05") if S and K else {}

    # objective
    obj_expansion = gp.quicksum(c1[f] * x1[f] + c2[f] * x2[f] + c3[f] * x3[f] for f in F) if F else 0
    obj_newbuild  = gp.quicksum(cost[k] * y_sk[s, k] for s in S for k in K) if S and K else 0
    obj_eqpt      = BETA * (gp.quicksum(z05[f] for f in F) + gp.quicksum(u_sk05[s, k] for s in S for k in K)) if ((F) or (S and K)) else 0
    m.setObjective(obj_expansion + obj_newbuild + obj_eqpt, GRB.MINIMIZE)

    # constraints
    # (a) piecewise expansion (only if F non-empty)
    for f in F:
        n = float(nf.get(f, 0))
        # segments are defined as fractions of n
        m.addConstr(x1[f] == 0.10 * n * y1[f], name=f"x1_def_{f}")
        m.addConstr(x2[f] == 0.05 * n * y2[f], name=f"x2_def_{f}")
        m.addConstr(x3[f] == 0.05 * n * y3[f], name=f"x3_def_{f}")
        # enforce ordered activation across continuous y's
        m.addConstr(y2[f] <= y1[f], name=f"y2_le_y1_{f}")
        m.addConstr(y3[f] <= y2[f], name=f"y3_le_y2_{f}")
        m.addConstr(xF[f] == x1[f] + x2[f] + x3[f], name=f"xF_def_{f}")
        m.addConstr(xF[f] <= 0.20 * n, name=f"xF_ub_{f}")
        m.addConstr(z05[f] <= xF[f], name=f"z05_le_xF_{f}")
 
    """ # (a) simplified expansion constraint (max 20% of current capacity)
    for f in F:
        n = float(nf.get(f, 0))
        
        # ensure non-negative expansion variable
        m.addConstr(xF[f] >= 0, name=f"xF_nonneg_{f}")
        
        # total expansion limited to 20% of existing capacity
        m.addConstr(xF[f] <= 0.20 * n, name=f"xF_ub_{f}")
        
        # link expansion for 0–5 slots if applicable
        # (assuming z05[f] is the expansion allocated to children 0–5)
        m.addConstr(z05[f] <= xF[f], name=f"z05_le_xF_{f}") """

    
    # (b) new site feasibility and 0-5 capacity
    for s in S:
        if allow.get(s, 1) == 0:
            # not allowed to build at this site
            m.addConstr(gp.quicksum(y_sk[s, k] for k in K) == 0, name=f"site_block_{s}")
        else:
            m.addConstr(gp.quicksum(y_sk[s, k] for k in K) <= 1, name=f"site_one_size_{s}")
        for k in K:
            m.addConstr(u_sk05[s, k] <= cap05[k] * y_sk[s, k], name=f"u_cap05_{s}_{k}")

    # (c) area total capacity coverage
    for i in I:
        # existing + expansions in area i
        existing = gp.quicksum(nf[f] + xF[f] for f in F if zip_f.get(f, "") == i) if F else 0
        newcap   = gp.quicksum(cap[k] * y_sk[s, k] for s in S if zip_s.get(s, "") == i for k in K) if (S and K) else 0
        rhs = ti.get(i, 1/3) * Pi.get(i, 0)
        # ensure rhs is numeric
        if pd.isna(rhs):
            rhs = 0
        m.addConstr(existing + newcap >= rhs, name=f"area_cover_{i}")

    # (d) area 0-5 coverage
    for i in I:
        exist05 = gp.quicksum(q05[f] + z05[f] for f in F if zip_f.get(f, "") == i) if F else 0
        new05   = gp.quicksum(u_sk05[s, k] for s in S if zip_s.get(s, "") == i for k in K) if (S and K) else 0
        rhs05 = (2.0/3.0) * Pi05.get(i, 0)
        if pd.isna(rhs05):
            rhs05 = 0
        m.addConstr(exist05 + new05 >= rhs05, name=f"area_05_cover_{i}")

    # (e) site conflict pairs (distance)
    for (s1, s2) in pairs:
        for k1 in K:
            for k2 in K:
                m.addConstr(y_sk[s1, k1] + y_sk[s2, k2] <= 1, name=f"conf_{s1}_{s2}_{k1}_{k2}")

    # done building
    return m, (xF, z05, y_sk, u_sk05)

# %%
# ------------------------------
# 9. Solve and print results + IIS analysis
# ------------------------------
def main():
    import pandas as pd
    import numpy as np
    import gurobipy as gp
    from gurobipy import GRB
    from itertools import combinations
    from pathlib import Path

    areas, facs, sites, sizes = load_data()

    # quick sanity checks
    print("[main] sample areas head:\n", areas.head().to_string(index=False))
    print("[main] sample facilities head:\n", facs.head().to_string(index=False))
    print("[main] sample sites head:\n", sites.head().to_string(index=False))

    sites = infer_sites(sites, facs)
    pairs = conflict_pairs(sites)

    print(f"[main] after infer_sites: allowed sites = {sites['allowed'].sum()} / {len(sites)}")

    # build and solve
    m, (xF, z05, y_sk, u_sk05) = build_model(
        areas, facs, sites, sizes, pairs,
        time_limit=120, mip_gap=0.01
    )

    print("[main] Starting optimization...")
    m.optimize()

    status = m.status
    print("[main] Solver status code:", status)

    if status in (GRB.Status.OPTIMAL, GRB.Status.TIME_LIMIT) and m.SolCount > 0:
        print("------ SOLUTION SUMMARY ------")
        print("Objective (Total Cost): ${:,.0f}".format(m.objVal))

        # --- selected new sites ---
        new_sites = []
        cap   = dict(zip(sizes.k, sizes.cap_k))
        cap05 = dict(zip(sizes.k, sizes.cap_k_0_5))
        zip_f = dict(zip(facs.facility_id, facs.zip_code_cleaned))
        zip_s = dict(zip(sites.site_id, sites.zip_code_cleaned))

        for (s, k) in list(y_sk.keys()):
            if y_sk[s, k].X > 0.5:
                new_sites.append({
                    "site_id": s,
                    "zip": zip_s.get(s, ""),
                    "size": k,
                    "cap_total": cap[k],
                    "cap_0_5": u_sk05[s, k].X
                })

        new_sites = sorted(new_sites, key=lambda r: (r["zip"], r["site_id"]))
        print("\n--- New Facilities Selected ---")
        if not new_sites:
            print("  (none)")
        else:
            for r in new_sites:
                print(f"  Site {r['site_id']} | ZIP {r['zip']} | Size {r['size']} "
                      f"| Total cap {r['cap_total']} | 0–5 slots {r['cap_0_5']:.1f}")

        # --- expansions ---
        exp_list = []
        for f in xF.keys():
            xf = xF[f].X
            zf5 = z05[f].X
            if xf > 1e-6 or zf5 > 1e-6:
                exp_list.append({
                    "facility_id": f,
                    "zip": zip_f.get(f, ""),
                    "expand": xf,
                    "add_0_5": zf5
                })

        exp_list = sorted(exp_list, key=lambda r: (r["zip"], r["facility_id"]))
        print("\n--- Facility Expansions ---")
        if not exp_list:
            print("  (none)")
        else:
            for r in exp_list:
                print(f"  Fac {r['facility_id']} | ZIP {r['zip']} | +{r['expand']:.1f} slots | 0–5 +{r['add_0_5']:.1f}")

        # --- totals ---
        total_new_cap = sum(r["cap_total"] for r in new_sites)
        total_new_05  = sum(r["cap_0_5"] for r in new_sites)
        total_exp_cap = sum(r["expand"] for r in exp_list)
        total_exp_05  = sum(r["add_0_5"] for r in exp_list)

        print("\n--- Totals ---")
        print(f"  New facilities: {len(new_sites)} | Total new capacity: {total_new_cap:.0f} | New 0–5 slots: {total_new_05:.1f}")
        print(f"  Expanded facilities: {len(exp_list)} | Total expansion: {total_exp_cap:.1f} | 0–5 from expansion: {total_exp_05:.1f}")
        print("-------------------------------")

    else:
        print("No feasible solution found or no solution returned. Solver status:", status, "SolCount:", m.SolCount)

        # ------------------------------
        # IIS Debugging (Automatic Analysis)
        # ------------------------------
        if status in [GRB.Status.INFEASIBLE, GRB.Status.INF_OR_UNBD]:
            print("\n[debug] Model infeasible; computing IIS...")

            m_feas = m.copy()
            m_feas.computeIIS()

            infeas_constrs = [c.constrName for c in m_feas.getConstrs() if c.IISConstr]
            print(f"[debug] {len(infeas_constrs)} infeasible constraints found.")

            # Try to extract ZIP codes from area constraints
            zip_list = []
            for c in infeas_constrs:
                if c.startswith("area_cover_") or c.startswith("area_05_cover_"):
                    parts = c.split("_")
                    zip_code = parts[-1]
                    zip_list.append(zip_code)

            if zip_list:
                print(f"[debug] Found {len(zip_list)} ZIPs causing infeasibility.")
                df_zip = pd.DataFrame({"infeasible_zip": zip_list})
                df_zip.to_csv("infeasible_zips_full.csv", index=False)
                print("[debug] Saved infeasible ZIPs to infeasible_zips.csv")

            else:
                print("[debug] No ZIP-specific infeasible constraints found.")

            # Export IIS report
            m_feas.write("model.ilp")
            m_feas.write("model.ilp.gz")
            m_feas.write("model.ilp.json")
            print("[debug] IIS written to 'model.ilp.*' files for inspection.")

        else:
            print("[debug] Model is not infeasible according to Gurobi status.")


if __name__ == "__main__":
    main()
# Out:
# [load_data] ZIP union: 1805 total (pop=1646, cls=1534)
# [load_data] Dropped infeasible ZIPs: ['11219']
# [load_data] areas: 1804, facilities (before filter): 15014, (after filter): 15013, sites: 215400
# [load_data] sample areas head:
#  zip_code_cleaned  pop_0_5  pop_0_12      t_i
#            06390      0.0       4.0 0.333333
#            10001    901.0    2093.0 0.333333
#            10002   2751.0    7107.0 0.500000
#            10003   1647.0    3046.0 0.333333
#            10004    469.0     712.0 0.333333
# [main] sample areas head:
#  zip_code_cleaned  pop_0_5  pop_0_12      t_i
#            06390      0.0       4.0 0.333333
#            10001    901.0    2093.0 0.333333
#            10002   2751.0    7107.0 0.500000
#            10003   1647.0    3046.0 0.333333
#            10004    469.0     712.0 0.333333
# [main] sample facilities head:
#   facility_id zip_code_cleaned  n_f  q_0_5       lat        lon
#        40163            10960  120    120 41.089425 -73.920413
#        41016            12077   75      0 42.607043 -73.788606
#        51349            10474    6      0 40.818399 -73.888816
#        73544            10017   60      0 40.753216 -73.970794
#       126425            10465   12      0 40.841228 -73.823572
# [main] sample sites head:
#   site_id zip_code_cleaned       lat        lon
#        1            00501 40.816376 -73.040796
#        2            00501 40.817455 -73.044202
#        3            00501 40.813873 -73.042182
#        4            00501 40.814152 -73.037265
#        5            00501 40.824673 -73.047431
# [conflict_pairs] conflict pairs found: 81383
# [main] after infer_sites: allowed sites = 211191 / 215400
# Set parameter OutputFlag to value 1
# Set parameter MIPGap to value 0.01
# Set parameter TimeLimit to value 120
# [main] Starting optimization...
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  120
# MIPGap  0.01
#
# Optimize a model with 1717759 rows, 1412504 columns and 4770939 nonzeros
# Model fingerprint: 0x27e84671
# Variable types: 766304 continuous, 646200 integer (646200 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+02]
#   Objective range  [1e+02, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [3e-01, 9e+03]
# Presolve removed 1458479 rows and 1008784 columns (presolve time = 28s)...
# Presolve removed 1458479 rows and 1008784 columns
# Presolve time: 28.54s
# Presolved: 259280 rows, 403720 columns, 1025163 nonzeros
# Variable types: 220954 continuous, 182766 integer (178266 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.160e+05
#  Factor NZ  : 3.556e+05 (roughly 50 MB of memory)
#  Factor Ops : 4.188e+06 (less than 1 second per iteration)
#  Threads    : 5
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.47364224e+11 -1.90922182e+11  9.19e+03 2.86e-11  5.02e+07    30s
#    1   6.01155624e+10 -1.87725009e+11  3.17e+03 7.49e+04  1.79e+07    30s
#    2   9.63277003e+09 -1.30331519e+11  3.16e+02 1.38e+04  2.34e+06    30s
#    3   4.34310740e+09 -4.63985750e+10  3.05e+01 1.21e+03  3.93e+05    30s
#    4   2.51856526e+09 -1.93273706e+10  2.94e+00 3.45e+02  1.31e+05    30s
#    5   1.85160340e+09 -8.43666898e+09  8.91e-01 7.03e+01  6.02e+04    30s
#    6   1.44768090e+09 -4.87921881e+09  3.82e-01 3.42e+01  3.67e+04    30s
#    7   1.21010165e+09 -1.84687755e+09  2.09e-01 2.63e+01  1.77e+04    30s
#    8   9.16620126e+08 -3.05506221e+08  8.15e-02 1.16e-10  7.05e+03    30s
#    9   7.98178614e+08  2.46565897e+07  5.42e-02 1.16e-10  4.46e+03    30s
#   10   6.78770272e+08  2.19297032e+08  3.17e-02 2.33e-10  2.65e+03    30s
#   11   5.86691476e+08  4.37830805e+08  1.46e-02 1.16e-10  8.57e+02    30s
#   12   5.61181304e+08  4.78646980e+08  9.92e-03 1.16e-10  4.75e+02    30s
#   13   5.50634116e+08  4.85776332e+08  7.95e-03 1.16e-10  3.73e+02    30s
#   14   5.42032522e+08  4.92307630e+08  6.29e-03 1.16e-10  2.86e+02    30s
#   15   5.37150641e+08  4.95344011e+08  5.34e-03 1.16e-10  2.41e+02    30s
#
# Barrier performed 15 iterations in 30.16 seconds (44.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.05s
#
# Solved with primal simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    31449    5.0886838e+08   0.000000e+00   0.000000e+00     30s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#    11873 DPushes remaining with DInf 0.0000000e+00                30s
#        0 DPushes remaining with DInf 0.0000000e+00                30s
#
#    19156 PPushes remaining with PInf 0.0000000e+00                30s
#        0 PPushes remaining with PInf 0.0000000e+00                31s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.7516296e-09     31s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    62000    5.0886838e+08   0.000000e+00   0.000000e+00     31s
#    62000    5.0886838e+08   0.000000e+00   0.000000e+00     31s
#
# Root relaxation: objective 5.088684e+08, 62000 iterations, 1.38 seconds (1.63 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5.0887e+08    0  521          - 5.0887e+08      -     -   33s
# H    0     0                    5.312961e+08 5.0887e+08  4.22%     -   33s
# H    0     0                    5.286127e+08 5.0887e+08  3.74%     -   34s
# H    0     0                    5.271632e+08 5.0887e+08  3.47%     -   34s
# H    0     0                    5.241157e+08 5.0887e+08  2.91%     -   34s
# H    0     0                    5.240357e+08 5.0887e+08  2.89%     -   34s
# H    0     0                    5.199882e+08 5.0887e+08  2.14%     -   35s
# H    0     0                    5.198582e+08 5.0887e+08  2.11%     -   35s
# H    0     0                    5.198082e+08 5.0887e+08  2.10%     -   35s
# H    0     0                    5.197918e+08 5.0887e+08  2.10%     -   36s
#      0     0 5.0887e+08    0  551 5.1979e+08 5.0887e+08  2.10%     -   39s
#      0     0 5.0887e+08    0  613 5.1979e+08 5.0887e+08  2.10%     -   42s
#      0     0 5.0887e+08    0  553 5.1979e+08 5.0887e+08  2.10%     -   44s
#      0     0 5.0887e+08    0  612 5.1979e+08 5.0887e+08  2.10%     -   45s
#      0     0 5.0887e+08    0  568 5.1979e+08 5.0887e+08  2.10%     -   47s
#      0     0 5.0895e+08    0  588 5.1979e+08 5.0895e+08  2.09%     -   50s
#      0     0 5.0995e+08    0  637 5.1979e+08 5.0995e+08  1.89%     -   50s
#      0     0 5.1133e+08    0  659 5.1979e+08 5.1133e+08  1.63%     -   50s
#      0     0 5.1209e+08    0  701 5.1979e+08 5.1209e+08  1.48%     -   51s
#      0     0 5.1267e+08    0  714 5.1979e+08 5.1267e+08  1.37%     -   51s
#      0     0 5.1317e+08    0  725 5.1979e+08 5.1317e+08  1.27%     -   51s
#      0     0 5.1342e+08    0  710 5.1979e+08 5.1342e+08  1.23%     -   51s
#      0     0 5.1357e+08    0  711 5.1979e+08 5.1357e+08  1.20%     -   52s
#      0     0 5.1364e+08    0  672 5.1979e+08 5.1364e+08  1.18%     -   52s
#      0     0 5.1366e+08    0  643 5.1979e+08 5.1366e+08  1.18%     -   52s
#      0     0 5.1375e+08    0  666 5.1979e+08 5.1375e+08  1.16%     -   52s
#      0     0 5.1384e+08    0  692 5.1979e+08 5.1384e+08  1.15%     -   53s
#      0     0 5.1385e+08    0  701 5.1979e+08 5.1385e+08  1.14%     -   53s
#      0     0 5.1385e+08    0  706 5.1979e+08 5.1385e+08  1.14%     -   53s
#      0     0 5.1385e+08    0  707 5.1979e+08 5.1385e+08  1.14%     -   53s
#      0     0 5.1385e+08    0  707 5.1979e+08 5.1385e+08  1.14%     -   54s
#      0     0 5.1402e+08    0  546 5.1979e+08 5.1402e+08  1.11%     -   57s
# H    0     0                    5.188788e+08 5.1402e+08  0.94%     -   57s
#
# Cutting planes:
#   Gomory: 96
#   Cover: 67
#   MIR: 489
#   StrongCG: 30
#   Flow cover: 416
#   GUB cover: 18
#   Network: 1
#
# Explored 1 nodes (97416 simplex iterations) in 57.66 seconds (86.46 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 5.18879e+08 5.18879e+08 5.19792e+08 ... 5.28613e+08
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 5.188787860300e+08, best bound 5.140164359555e+08, gap 0.9371%
# [main] Solver status code: 2
# ------ SOLUTION SUMMARY ------
# Objective (Total Cost): $518,878,786
#
# --- New Facilities Selected ---
#   Site 300 | ZIP 06390 | Size S | Total cap 100 | 0–5 slots 0.0
#   Site 302 | ZIP 10001 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 307 | ZIP 10001 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 389 | ZIP 10001 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 404 | ZIP 10002 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 408 | ZIP 10002 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 426 | ZIP 10002 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 427 | ZIP 10002 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 446 | ZIP 10002 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 479 | ZIP 10002 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 534 | ZIP 10003 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 577 | ZIP 10003 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 581 | ZIP 10003 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 594 | ZIP 10003 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 655 | ZIP 10004 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 684 | ZIP 10004 | Size M | Total cap 200 | 0–5 slots 100.0
#   Site 725 | ZIP 10005 | Size L | Total cap 400 | 0–5 slots 150.0
#   Site 779 | ZIP 10005 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 885 | ZIP 10006 | Size M | Total cap 200 | 0–5 slots 84.0
#   Site 943 | ZIP 10007 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 966 | ZIP 10007 | Size S | Total cap 100 | 0–5 slots 50.0
#   Site 978 | ZIP 10007 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1110 | ZIP 10009 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1120 | ZIP 10009 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1133 | ZIP 10009 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1148 | ZIP 10009 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1169 | ZIP 10009 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1197 | ZIP 10009 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1203 | ZIP 10010 | Size L | Total cap 400 | 0–5 slots 160.0
#   Site 1209 | ZIP 10010 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1232 | ZIP 10010 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1250 | ZIP 10010 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1269 | ZIP 10010 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1287 | ZIP 10010 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1359 | ZIP 10011 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1388 | ZIP 10011 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1400 | ZIP 10011 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1414 | ZIP 10012 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1485 | ZIP 10012 | Size L | Total cap 400 | 0–5 slots 180.0
#   Site 1491 | ZIP 10012 | Size S | Total cap 100 | 0–5 slots 50.0
#   Site 1501 | ZIP 10013 | Size L | Total cap 400 | 0–5 slots 180.7
#   Site 1502 | ZIP 10013 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1524 | ZIP 10013 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1531 | ZIP 10013 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1563 | ZIP 10013 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1686 | ZIP 10014 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1729 | ZIP 10016 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1735 | ZIP 10016 | Size S | Total cap 100 | 0–5 slots 50.0
#   Site 1755 | ZIP 10016 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1770 | ZIP 10016 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1771 | ZIP 10016 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1794 | ZIP 10016 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1795 | ZIP 10016 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 1882 | ZIP 10017 | Size L | Total cap 400 | 0–5 slots 152.0
#   Site 1982 | ZIP 10018 | Size L | Total cap 400 | 0–5 slots 190.7
#   Site 2005 | ZIP 10019 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2017 | ZIP 10019 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2031 | ZIP 10019 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2045 | ZIP 10019 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2214 | ZIP 10021 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2219 | ZIP 10021 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2222 | ZIP 10021 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2248 | ZIP 10021 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2251 | ZIP 10021 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2263 | ZIP 10021 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2278 | ZIP 10021 | Size M | Total cap 200 | 0–5 slots 100.0
#   Site 2303 | ZIP 10022 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2330 | ZIP 10022 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2331 | ZIP 10022 | Size L | Total cap 400 | 0–5 slots 142.0
#   Site 2365 | ZIP 10022 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2400 | ZIP 10022 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2404 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2405 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2411 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2422 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2423 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2426 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2436 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2451 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2463 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2464 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2466 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2471 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2500 | ZIP 10023 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2503 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2504 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2505 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2509 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2514 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2515 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2523 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2527 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2534 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2561 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2563 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2564 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2570 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2572 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2587 | ZIP 10024 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2605 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2606 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2609 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2617 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2634 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2637 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2639 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2645 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2646 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2651 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2656 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2672 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2681 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2683 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2688 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2692 | ZIP 10025 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2715 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2718 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2728 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2729 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2741 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2745 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2748 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2784 | ZIP 10026 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2803 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2814 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2819 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2821 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2825 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2846 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2848 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2853 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2859 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2867 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2869 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2900 | ZIP 10027 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2901 | ZIP 10028 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2911 | ZIP 10028 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2918 | ZIP 10028 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2928 | ZIP 10028 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2945 | ZIP 10028 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2963 | ZIP 10028 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 2987 | ZIP 10028 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3003 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3008 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3029 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3040 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3049 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3057 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3059 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3067 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3071 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3072 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3076 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3084 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3086 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3096 | ZIP 10029 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3103 | ZIP 10030 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3108 | ZIP 10030 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3114 | ZIP 10030 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3120 | ZIP 10030 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3137 | ZIP 10030 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3159 | ZIP 10030 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3179 | ZIP 10030 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3203 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3217 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3220 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3224 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3233 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3235 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3245 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3282 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3291 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3293 | ZIP 10031 | Size L | Total cap 400 | 0–5 slots 160.0
#   Site 3309 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3324 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3327 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3337 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3349 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3362 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3380 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3393 | ZIP 10032 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3408 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3411 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3416 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3425 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3426 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3434 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3437 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3439 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3443 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3469 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3470 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3499 | ZIP 10033 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3513 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3526 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3528 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3535 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3542 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3554 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3569 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3583 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3593 | ZIP 10034 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3604 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3605 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3611 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3615 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3616 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3637 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3644 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3664 | ZIP 10035 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3739 | ZIP 10036 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3771 | ZIP 10036 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3842 | ZIP 10037 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3888 | ZIP 10037 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3898 | ZIP 10037 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3900 | ZIP 10037 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3911 | ZIP 10038 | Size L | Total cap 400 | 0–5 slots 166.0
#   Site 3922 | ZIP 10038 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 3999 | ZIP 10038 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4003 | ZIP 10039 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4008 | ZIP 10039 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4034 | ZIP 10039 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4044 | ZIP 10039 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4054 | ZIP 10039 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4070 | ZIP 10039 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4076 | ZIP 10039 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4104 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4105 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4112 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4114 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4123 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4128 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4134 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4154 | ZIP 10040 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4424 | ZIP 10044 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4426 | ZIP 10044 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4432 | ZIP 10044 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4803 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4806 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4808 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4823 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4836 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4856 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4867 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4878 | ZIP 10065 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4908 | ZIP 10069 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4955 | ZIP 10069 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 4999 | ZIP 10069 | Size M | Total cap 200 | 0–5 slots 96.0
#   Site 5024 | ZIP 10075 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 5045 | ZIP 10075 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 5062 | ZIP 10075 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 5097 | ZIP 10075 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 5099 | ZIP 10075 | Size M | Total cap 200 | 0–5 slots 100.0
#   Site 8101 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8102 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8107 | ZIP 10128 | Size S | Total cap 100 | 0–5 slots 50.0
#   Site 8108 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8136 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8156 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8166 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8167 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8170 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8174 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 8200 | ZIP 10128 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 10062 | ZIP 10162 | Size M | Total cap 200 | 0–5 slots 89.3
#   Site 14404 | ZIP 10280 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14608 | ZIP 10282 | Size L | Total cap 400 | 0–5 slots 154.0
#   Site 14633 | ZIP 10282 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14902 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14912 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14915 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14936 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14950 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14967 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14980 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14988 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 14994 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15000 | ZIP 10301 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15001 | ZIP 10302 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15064 | ZIP 10302 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15089 | ZIP 10302 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15098 | ZIP 10302 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15100 | ZIP 10302 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15111 | ZIP 10303 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15117 | ZIP 10303 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15124 | ZIP 10303 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15127 | ZIP 10303 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15180 | ZIP 10303 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15201 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15204 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15214 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15215 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15216 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15232 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15238 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15251 | ZIP 10304 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15308 | ZIP 10305 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15317 | ZIP 10305 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15321 | ZIP 10305 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15322 | ZIP 10305 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15331 | ZIP 10305 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15353 | ZIP 10305 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15361 | ZIP 10305 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15401 | ZIP 10306 | Size M | Total cap 200 | 0–5 slots 100.0
#   Site 15404 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15419 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15433 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15442 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15449 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15459 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15472 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15478 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15487 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15488 | ZIP 10306 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15518 | ZIP 10307 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15530 | ZIP 10307 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15566 | ZIP 10307 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15587 | ZIP 10307 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15605 | ZIP 10308 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15613 | ZIP 10308 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15625 | ZIP 10308 | Size L | Total cap 400 | 0–5 slots 152.0
#   Site 15626 | ZIP 10308 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15657 | ZIP 10308 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15701 | ZIP 10309 | Size M | Total cap 200 | 0–5 slots 100.0
#   Site 15703 | ZIP 10309 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15704 | ZIP 10309 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15708 | ZIP 10309 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15716 | ZIP 10309 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15763 | ZIP 10309 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15776 | ZIP 10309 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15799 | ZIP 10309 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15804 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15842 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15845 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15848 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15868 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15879 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15887 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 15895 | ZIP 10310 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16004 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16005 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16011 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16018 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16019 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16025 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16027 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16031 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16033 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16034 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16048 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16052 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16059 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16067 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16079 | ZIP 10312 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16202 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16207 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16210 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16214 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16216 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16222 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16229 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16238 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16241 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16244 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16247 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16252 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16255 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16258 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16260 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16261 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16269 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16282 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16284 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16287 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16289 | ZIP 10314 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16305 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16319 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16324 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16331 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16343 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16345 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16360 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16361 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16368 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16375 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16380 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16391 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16395 | ZIP 10451 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16405 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16406 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16413 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16421 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16423 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16432 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16433 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16437 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16444 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16447 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16453 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16455 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16461 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16465 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16472 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16475 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16480 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16490 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16491 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16499 | ZIP 10452 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16502 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16504 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16506 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16511 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16515 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16526 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16529 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16531 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16540 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16541 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16546 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16551 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16553 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16565 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16566 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16568 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16573 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16581 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16593 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16600 | ZIP 10453 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16602 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16605 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16629 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16632 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16640 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16651 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16656 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16659 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16687 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16693 | ZIP 10454 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16701 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16704 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16706 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16727 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16729 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16736 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16740 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16743 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16764 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16769 | ZIP 10455 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16802 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16804 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16808 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16815 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16819 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16821 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16824 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16827 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16832 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16838 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16848 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16851 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16856 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16858 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16863 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16866 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16867 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16871 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16881 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16884 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16885 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16888 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16889 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16894 | ZIP 10456 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16905 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16908 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16910 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16913 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16919 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16920 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16924 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16926 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16930 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16931 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16932 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16933 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16935 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16939 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16942 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16944 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16947 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16948 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16951 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16953 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16954 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16955 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16959 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16965 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 16988 | ZIP 10457 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17006 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17008 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17013 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17019 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17021 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17023 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17028 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17031 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17034 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17038 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17046 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17051 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17053 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17062 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17070 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17073 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17075 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17080 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17081 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17086 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17091 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17100 | ZIP 10458 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17109 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17112 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17115 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17118 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17120 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17121 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17125 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17129 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17152 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17163 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17166 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17170 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17176 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17200 | ZIP 10459 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17212 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17215 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17228 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17231 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17241 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17245 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17257 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17260 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17261 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17282 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17287 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17291 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17296 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17297 | ZIP 10460 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17302 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17308 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17309 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17312 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17326 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17327 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17349 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17352 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17357 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17359 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17362 | ZIP 10461 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17407 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17410 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17417 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17421 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17431 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17433 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17435 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17440 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17442 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17444 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17451 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17454 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17456 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17459 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17461 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17470 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17477 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17482 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17490 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17494 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17497 | ZIP 10462 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17502 | ZIP 10463 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17508 | ZIP 10463 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17513 | ZIP 10463 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17520 | ZIP 10463 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17542 | ZIP 10463 | Size L | Total cap 400 | 0–5 slots 200.0
#   Site 17545 | ZIP 10463 | Size L | Total cap 400 | 0–5 slots 200.0
# ...
#   Fac 41550 | ZIP 13088 | +18.8 slots | 0–5 +18.8
#   Fac 44937 | ZIP 13088 | +12.9 slots | 0–5 +12.9
#   Fac 361699 | ZIP 13088 | +23.2 slots | 0–5 +23.2
#   Fac 715118 | ZIP 13088 | +9.9 slots | 0–5 +9.9
#   Fac 827048 | ZIP 13088 | +9.0 slots | 0–5 +9.0
#   Fac 42082 | ZIP 13126 | +5.2 slots | 0–5 +5.2
#   Fac 249551 | ZIP 13126 | +11.7 slots | 0–5 +11.7
#   Fac 878636 | ZIP 13126 | +5.0 slots | 0–5 +5.0
#   Fac 900947 | ZIP 13126 | +15.8 slots | 0–5 +15.8
#   Fac 920088 | ZIP 13126 | +5.0 slots | 0–5 +5.0
#   Fac 920210 | ZIP 13126 | +5.0 slots | 0–5 +5.0
#   Fac 920211 | ZIP 13126 | +6.7 slots | 0–5 +6.7
#   Fac 42191 | ZIP 13135 | +8.6 slots | 0–5 +8.6
#   Fac 901528 | ZIP 13135 | +3.4 slots | 0–5 +3.4
#   Fac 40488 | ZIP 13143 | +11.3 slots | 0–5 +11.3
#   Fac 43980 | ZIP 13152 | +13.0 slots | 0–5 +13.0
#   Fac 896468 | ZIP 13152 | +9.0 slots | 0–5 +9.0
#   Fac 42303 | ZIP 13166 | +0.7 slots | 0–5 +0.7
#   Fac 42279 | ZIP 13202 | +4.6 slots | 0–5 +4.6
#   Fac 351583 | ZIP 13202 | +13.4 slots | 0–5 +13.4
#   Fac 40714 | ZIP 13203 | +6.7 slots | 0–5 +6.7
#   Fac 41889 | ZIP 13203 | +10.6 slots | 0–5 +10.6
#   Fac 40023 | ZIP 13204 | +6.0 slots | 0–5 +6.0
#   Fac 42728 | ZIP 13205 | +26.0 slots | 0–5 +26.0
#   Fac 44119 | ZIP 13205 | +6.0 slots | 0–5 +6.0
#   Fac 445591 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 573188 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 834454 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 836277 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 847817 | ZIP 13205 | +1.5 slots | 0–5 +1.5
#   Fac 868613 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 879479 | ZIP 13205 | +10.2 slots | 0–5 +10.2
#   Fac 887480 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 891177 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 898080 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 904585 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 914776 | ZIP 13205 | +1.6 slots | 0–5 +1.6
#   Fac 44240 | ZIP 13209 | +10.5 slots | 0–5 +10.5
#   Fac 467260 | ZIP 13209 | +5.2 slots | 0–5 +5.2
#   Fac 40027 | ZIP 13210 | +21.0 slots | 0–5 +21.0
#   Fac 714196 | ZIP 13210 | +3.4 slots | 0–5 +3.4
#   Fac 883933 | ZIP 13210 | +4.9 slots | 0–5 +4.9
#   Fac 876923 | ZIP 13211 | +7.1 slots | 0–5 +7.1
#   Fac 905322 | ZIP 13211 | +1.6 slots | 0–5 +1.6
#   Fac 42108 | ZIP 13215 | +11.2 slots | 0–5 +11.2
#   Fac 45207 | ZIP 13215 | +10.8 slots | 0–5 +10.8
#   Fac 311480 | ZIP 13215 | +8.2 slots | 0–5 +8.2
#   Fac 889013 | ZIP 13215 | +2.5 slots | 0–5 +2.5
#   Fac 42459 | ZIP 13219 | +4.6 slots | 0–5 +4.6
#   Fac 799188 | ZIP 13219 | +13.7 slots | 0–5 +13.7
#   Fac 883862 | ZIP 13219 | +13.1 slots | 0–5 +13.1
#   Fac 399551 | ZIP 13323 | +5.7 slots | 0–5 +5.7
#   Fac 695907 | ZIP 13323 | +15.9 slots | 0–5 +15.9
#   Fac 825128 | ZIP 13323 | +7.1 slots | 0–5 +7.1
#   Fac 39609 | ZIP 13346 | +13.5 slots | 0–5 +13.5
#   Fac 431946 | ZIP 13346 | +5.2 slots | 0–5 +5.2
#   Fac 45043 | ZIP 13365 | +10.7 slots | 0–5 +10.7
#   Fac 915459 | ZIP 13365 | +4.3 slots | 0–5 +4.3
#   Fac 39593 | ZIP 13367 | +4.3 slots | 0–5 +4.3
#   Fac 42517 | ZIP 13367 | +16.0 slots | 0–5 +16.0
#   Fac 159141 | ZIP 13367 | +14.4 slots | 0–5 +14.4
#   Fac 875901 | ZIP 13367 | +1.6 slots | 0–5 +1.6
#   Fac 885779 | ZIP 13367 | +1.6 slots | 0–5 +1.6
#   Fac 892545 | ZIP 13367 | +1.1 slots | 0–5 +1.1
#   Fac 761617 | ZIP 13403 | +12.7 slots | 0–5 +12.7
#   Fac 840711 | ZIP 13411 | +5.0 slots | 0–5 +5.0
#   Fac 131801 | ZIP 13413 | +4.8 slots | 0–5 +4.8
#   Fac 536937 | ZIP 13413 | +10.5 slots | 0–5 +10.5
#   Fac 115003 | ZIP 13421 | +2.8 slots | 0–5 +2.8
#   Fac 195607 | ZIP 13421 | +12.9 slots | 0–5 +12.9
#   Fac 39935 | ZIP 13424 | +6.0 slots | 0–5 +6.0
#   Fac 42537 | ZIP 13440 | +7.2 slots | 0–5 +7.2
#   Fac 42878 | ZIP 13440 | +13.1 slots | 0–5 +13.1
#   Fac 867002 | ZIP 13452 | +1.3 slots | 0–5 +1.3
#   Fac 42787 | ZIP 13492 | +19.3 slots | 0–5 +19.3
#   Fac 39947 | ZIP 13501 | +8.1 slots | 0–5 +8.1
#   Fac 39953 | ZIP 13501 | +12.2 slots | 0–5 +12.2
#   Fac 41536 | ZIP 13501 | +12.0 slots | 0–5 +12.0
#   Fac 129128 | ZIP 13501 | +10.4 slots | 0–5 +10.4
#   Fac 223832 | ZIP 13501 | +11.9 slots | 0–5 +11.9
#   Fac 253607 | ZIP 13501 | +10.8 slots | 0–5 +10.8
#   Fac 735631 | ZIP 13501 | +13.7 slots | 0–5 +13.7
#   Fac 741593 | ZIP 13501 | +8.0 slots | 0–5 +8.0
#   Fac 828691 | ZIP 13501 | +32.2 slots | 0–5 +32.2
#   Fac 39589 | ZIP 13601 | +21.9 slots | 0–5 +21.9
#   Fac 40860 | ZIP 13601 | +6.4 slots | 0–5 +6.4
#   Fac 41465 | ZIP 13601 | +17.3 slots | 0–5 +17.3
#   Fac 42429 | ZIP 13601 | +6.0 slots | 0–5 +6.0
#   Fac 42431 | ZIP 13601 | +24.0 slots | 0–5 +24.0
#   Fac 310646 | ZIP 13601 | +18.6 slots | 0–5 +18.6
#   Fac 434192 | ZIP 13601 | +7.6 slots | 0–5 +7.6
#   Fac 715017 | ZIP 13601 | +22.5 slots | 0–5 +22.5
#   Fac 797483 | ZIP 13601 | +30.0 slots | 0–5 +30.0
#   Fac 855344 | ZIP 13601 | +10.0 slots | 0–5 +10.0
#   Fac 876834 | ZIP 13601 | +18.0 slots | 0–5 +18.0
#   Fac 877265 | ZIP 13601 | +10.0 slots | 0–5 +10.0
#   Fac 877266 | ZIP 13601 | +10.0 slots | 0–5 +10.0
#   Fac 904014 | ZIP 13601 | +11.0 slots | 0–5 +11.0
#   Fac 797478 | ZIP 13605 | +10.0 slots | 0–5 +10.0
#   Fac 43208 | ZIP 13615 | +9.3 slots | 0–5 +9.3
#   Fac 44793 | ZIP 13620 | +6.0 slots | 0–5 +6.0
#   Fac 797480 | ZIP 13620 | +19.0 slots | 0–5 +19.0
#   Fac 889283 | ZIP 13630 | +24.0 slots | 0–5 +24.0
#   Fac 767756 | ZIP 13637 | +5.0 slots | 0–5 +5.0
#   Fac 877267 | ZIP 13637 | +9.0 slots | 0–5 +9.0
#   Fac 40182 | ZIP 13642 | +0.7 slots | 0–5 +0.7
#   Fac 797482 | ZIP 13656 | +4.0 slots | 0–5 +4.0
#   Fac 372917 | ZIP 13662 | +6.5 slots | 0–5 +0.0
#   Fac 394671 | ZIP 13668 | +9.2 slots | 0–5 +9.2
#   Fac 737116 | ZIP 13668 | +0.1 slots | 0–5 +0.1
#   Fac 575774 | ZIP 13753 | +4.3 slots | 0–5 +4.3
#   Fac 845207 | ZIP 13754 | +2.5 slots | 0–5 +2.5
#   Fac 150851 | ZIP 13760 | +4.0 slots | 0–5 +4.0
#   Fac 42273 | ZIP 13775 | +2.7 slots | 0–5 +2.7
#   Fac 900008 | ZIP 13775 | +19.6 slots | 0–5 +19.6
#   Fac 907486 | ZIP 13775 | +2.4 slots | 0–5 +2.4
#   Fac 900988 | ZIP 13776 | +2.0 slots | 0–5 +2.0
#   Fac 351914 | ZIP 13783 | +15.2 slots | 0–5 +15.2
#   Fac 351915 | ZIP 13783 | +13.5 slots | 0–5 +13.5
#   Fac 171899 | ZIP 13790 | +9.7 slots | 0–5 +9.7
#   Fac 245880 | ZIP 13790 | +23.0 slots | 0–5 +23.0
#   Fac 42295 | ZIP 13815 | +18.0 slots | 0–5 +18.0
#   Fac 43353 | ZIP 13815 | +15.0 slots | 0–5 +15.0
#   Fac 851919 | ZIP 13815 | +3.8 slots | 0–5 +3.8
#   Fac 882250 | ZIP 13815 | +6.0 slots | 0–5 +6.0
#   Fac 890950 | ZIP 13815 | +0.9 slots | 0–5 +0.9
#   Fac 40111 | ZIP 13820 | +28.2 slots | 0–5 +0.0
#   Fac 43747 | ZIP 13820 | +6.6 slots | 0–5 +0.0
#   Fac 157449 | ZIP 13820 | +7.0 slots | 0–5 +7.0
#   Fac 605549 | ZIP 13820 | +14.6 slots | 0–5 +0.0
#   Fac 608863 | ZIP 13820 | +6.6 slots | 0–5 +5.6
#   Fac 887911 | ZIP 13820 | +21.0 slots | 0–5 +0.0
#   Fac 17553 | ZIP 13838 | +1.6 slots | 0–5 +0.0
#   Fac 39324 | ZIP 13838 | +7.5 slots | 0–5 +0.0
#   Fac 41135 | ZIP 13838 | +41.8 slots | 0–5 +0.0
#   Fac 886716 | ZIP 13838 | +1.6 slots | 0–5 +0.0
#   Fac 883464 | ZIP 13842 | +1.3 slots | 0–5 +1.3
#   Fac 39242 | ZIP 13901 | +8.4 slots | 0–5 +8.4
#   Fac 40747 | ZIP 13901 | +8.0 slots | 0–5 +8.0
#   Fac 238729 | ZIP 13901 | +3.7 slots | 0–5 +3.7
#   Fac 321757 | ZIP 13901 | +7.2 slots | 0–5 +7.2
#   Fac 275912 | ZIP 13903 | +14.4 slots | 0–5 +14.4
#   Fac 445458 | ZIP 13903 | +6.5 slots | 0–5 +6.5
#   Fac 869683 | ZIP 13903 | +9.8 slots | 0–5 +9.8
#   Fac 521465 | ZIP 14006 | +4.0 slots | 0–5 +4.0
#   Fac 569563 | ZIP 14006 | +4.4 slots | 0–5 +4.4
#   Fac 917657 | ZIP 14006 | +6.3 slots | 0–5 +6.3
#   Fac 887370 | ZIP 14011 | +1.3 slots | 0–5 +1.3
#   Fac 39489 | ZIP 14025 | +10.7 slots | 0–5 +10.7
#   Fac 40641 | ZIP 14032 | +4.0 slots | 0–5 +4.0
#   Fac 663351 | ZIP 14036 | +6.3 slots | 0–5 +6.3
#   Fac 42765 | ZIP 14040 | +4.7 slots | 0–5 +4.7
#   Fac 39462 | ZIP 14043 | +13.0 slots | 0–5 +13.0
#   Fac 42628 | ZIP 14043 | +10.2 slots | 0–5 +10.2
#   Fac 332252 | ZIP 14043 | +16.4 slots | 0–5 +16.4
#   Fac 713313 | ZIP 14043 | +9.0 slots | 0–5 +9.0
#   Fac 891281 | ZIP 14043 | +7.7 slots | 0–5 +7.7
#   Fac 39415 | ZIP 14047 | +16.7 slots | 0–5 +16.7
#   Fac 43716 | ZIP 14047 | +5.4 slots | 0–5 +5.4
#   Fac 276047 | ZIP 14047 | +8.6 slots | 0–5 +8.6
#   Fac 42848 | ZIP 14048 | +7.5 slots | 0–5 +7.5
#   Fac 171422 | ZIP 14048 | +24.3 slots | 0–5 +24.3
#   Fac 877494 | ZIP 14048 | +16.5 slots | 0–5 +16.5
#   Fac 924727 | ZIP 14048 | +14.4 slots | 0–5 +14.4
#   Fac 44896 | ZIP 14051 | +28.4 slots | 0–5 +28.4
#   Fac 523803 | ZIP 14051 | +26.0 slots | 0–5 +26.0
#   Fac 777203 | ZIP 14051 | +18.9 slots | 0–5 +18.9
#   Fac 778703 | ZIP 14067 | +0.1 slots | 0–5 +0.1
#   Fac 918822 | ZIP 14067 | +11.2 slots | 0–5 +11.2
#   Fac 43822 | ZIP 14085 | +6.3 slots | 0–5 +6.3
#   Fac 168846 | ZIP 14085 | +3.8 slots | 0–5 +3.8
#   Fac 787715 | ZIP 14085 | +5.6 slots | 0–5 +5.6
#   Fac 39891 | ZIP 14092 | +13.2 slots | 0–5 +13.2
#   Fac 538069 | ZIP 14092 | +8.8 slots | 0–5 +8.8
#   Fac 653794 | ZIP 14094 | +12.7 slots | 0–5 +12.7
#   Fac 39409 | ZIP 14127 | +15.3 slots | 0–5 +15.3
#   Fac 39461 | ZIP 14127 | +11.1 slots | 0–5 +11.1
#   Fac 40880 | ZIP 14127 | +5.1 slots | 0–5 +5.1
#   Fac 274613 | ZIP 14127 | +24.6 slots | 0–5 +24.6
#   Fac 352720 | ZIP 14127 | +19.1 slots | 0–5 +19.1
#   Fac 734612 | ZIP 14127 | +18.1 slots | 0–5 +18.1
#   Fac 803185 | ZIP 14127 | +10.5 slots | 0–5 +10.5
#   Fac 879777 | ZIP 14127 | +27.0 slots | 0–5 +27.0
#   Fac 883033 | ZIP 14127 | +14.8 slots | 0–5 +14.8
#   Fac 879173 | ZIP 14131 | +22.0 slots | 0–5 +22.0
#   Fac 876990 | ZIP 14150 | +6.0 slots | 0–5 +6.0
#   Fac 42974 | ZIP 14174 | +1.2 slots | 0–5 +1.2
#   Fac 773086 | ZIP 14174 | +12.8 slots | 0–5 +12.8
#   Fac 163466 | ZIP 14202 | +8.4 slots | 0–5 +8.4
#   Fac 816477 | ZIP 14202 | +4.8 slots | 0–5 +4.8
#   Fac 869155 | ZIP 14202 | +11.8 slots | 0–5 +11.8
#   Fac 894574 | ZIP 14202 | +20.0 slots | 0–5 +20.0
#   Fac 868942 | ZIP 14204 | +22.8 slots | 0–5 +22.8
#   Fac 887360 | ZIP 14204 | +9.9 slots | 0–5 +9.9
#   Fac 42237 | ZIP 14206 | +6.6 slots | 0–5 +6.6
#   Fac 43041 | ZIP 14206 | +8.6 slots | 0–5 +8.6
#   Fac 787763 | ZIP 14206 | +15.4 slots | 0–5 +15.4
#   Fac 801864 | ZIP 14206 | +6.6 slots | 0–5 +6.6
#   Fac 831317 | ZIP 14206 | +4.3 slots | 0–5 +4.3
#   Fac 39470 | ZIP 14207 | +14.9 slots | 0–5 +14.9
#   Fac 43113 | ZIP 14207 | +11.7 slots | 0–5 +11.7
#   Fac 213345 | ZIP 14207 | +14.4 slots | 0–5 +14.4
#   Fac 357454 | ZIP 14211 | +12.4 slots | 0–5 +12.4
#   Fac 900557 | ZIP 14211 | +2.9 slots | 0–5 +2.9
#   Fac 44483 | ZIP 14212 | +6.6 slots | 0–5 +6.6
#   Fac 45319 | ZIP 14212 | +9.5 slots | 0–5 +9.5
#   Fac 771963 | ZIP 14212 | +14.9 slots | 0–5 +14.9
#   Fac 39439 | ZIP 14213 | +14.8 slots | 0–5 +14.8
#   Fac 45292 | ZIP 14213 | +18.0 slots | 0–5 +18.0
#   Fac 728794 | ZIP 14213 | +6.8 slots | 0–5 +6.8
#   Fac 871144 | ZIP 14213 | +4.4 slots | 0–5 +4.4
#   Fac 42685 | ZIP 14214 | +12.9 slots | 0–5 +12.9
#   Fac 762070 | ZIP 14214 | +14.5 slots | 0–5 +14.5
#   Fac 793224 | ZIP 14214 | +4.9 slots | 0–5 +4.9
#   Fac 273422 | ZIP 14215 | +8.9 slots | 0–5 +8.9
#   Fac 306259 | ZIP 14215 | +16.6 slots | 0–5 +16.6
#   Fac 467916 | ZIP 14215 | +15.0 slots | 0–5 +15.0
#   Fac 569566 | ZIP 14215 | +4.4 slots | 0–5 +4.4
#   Fac 891832 | ZIP 14215 | +7.4 slots | 0–5 +7.4
#   Fac 131026 | ZIP 14216 | +7.6 slots | 0–5 +7.6
#   Fac 834621 | ZIP 14216 | +5.4 slots | 0–5 +5.4
#   Fac 837321 | ZIP 14216 | +8.0 slots | 0–5 +8.0
#   Fac 39395 | ZIP 14217 | +12.9 slots | 0–5 +12.9
#   Fac 39487 | ZIP 14217 | +1.3 slots | 0–5 +1.3
#   Fac 239562 | ZIP 14217 | +11.3 slots | 0–5 +11.3
#   Fac 371407 | ZIP 14217 | +9.2 slots | 0–5 +9.2
#   Fac 359210 | ZIP 14218 | +17.0 slots | 0–5 +17.0
#   Fac 773947 | ZIP 14218 | +15.5 slots | 0–5 +15.5
#   Fac 777654 | ZIP 14218 | +2.8 slots | 0–5 +2.8
#   Fac 735792 | ZIP 14219 | +4.3 slots | 0–5 +4.3
#   Fac 39403 | ZIP 14221 | +15.9 slots | 0–5 +15.9
#   Fac 39407 | ZIP 14221 | +15.3 slots | 0–5 +15.3
#   Fac 43564 | ZIP 14221 | +6.5 slots | 0–5 +6.5
#   Fac 44235 | ZIP 14221 | +13.4 slots | 0–5 +13.4
#   Fac 44661 | ZIP 14221 | +14.7 slots | 0–5 +14.7
#   Fac 181991 | ZIP 14221 | +6.7 slots | 0–5 +6.7
#   Fac 384133 | ZIP 14221 | +24.6 slots | 0–5 +24.6
#   Fac 523798 | ZIP 14221 | +15.0 slots | 0–5 +15.0
#   Fac 523804 | ZIP 14221 | +15.0 slots | 0–5 +15.0
#   Fac 523806 | ZIP 14221 | +18.9 slots | 0–5 +18.9
#   Fac 523807 | ZIP 14221 | +15.0 slots | 0–5 +15.0
#   Fac 523808 | ZIP 14221 | +21.0 slots | 0–5 +21.0
#   Fac 804143 | ZIP 14221 | +18.0 slots | 0–5 +18.0
#   Fac 815516 | ZIP 14221 | +19.5 slots | 0–5 +19.5
#   Fac 829005 | ZIP 14221 | +23.1 slots | 0–5 +23.1
#   Fac 874399 | ZIP 14221 | +13.5 slots | 0–5 +13.5
#   Fac 883054 | ZIP 14221 | +17.2 slots | 0–5 +17.2
#   Fac 888677 | ZIP 14221 | +15.0 slots | 0–5 +15.0
#   Fac 39475 | ZIP 14226 | +24.0 slots | 0–5 +24.0
#   Fac 41820 | ZIP 14226 | +11.0 slots | 0–5 +11.0
#   Fac 802887 | ZIP 14226 | +12.0 slots | 0–5 +12.0
#   Fac 827160 | ZIP 14226 | +27.0 slots | 0–5 +27.0
#   Fac 827693 | ZIP 14226 | +13.6 slots | 0–5 +13.6
#   Fac 907075 | ZIP 14226 | +11.4 slots | 0–5 +11.4
#   Fac 42251 | ZIP 14228 | +5.1 slots | 0–5 +5.1
#   Fac 192915 | ZIP 14228 | +14.6 slots | 0–5 +14.6
#   Fac 218934 | ZIP 14228 | +9.9 slots | 0–5 +9.9
#   Fac 443194 | ZIP 14228 | +9.7 slots | 0–5 +9.7
#   Fac 324538 | ZIP 14303 | +1.1 slots | 0–5 +1.1
#   Fac 789518 | ZIP 14303 | +8.2 slots | 0–5 +8.2
#   Fac 299022 | ZIP 14414 | +24.0 slots | 0–5 +24.0
#   Fac 532996 | ZIP 14414 | +2.0 slots | 0–5 +2.0
#   Fac 837691 | ZIP 14414 | +17.3 slots | 0–5 +17.3
#   Fac 375358 | ZIP 14425 | +4.3 slots | 0–5 +4.3
#   Fac 105304 | ZIP 14432 | +8.0 slots | 0–5 +8.0
#   Fac 652188 | ZIP 14437 | +7.2 slots | 0–5 +7.2
#   Fac 659979 | ZIP 14437 | +20.8 slots | 0–5 +20.8
#   Fac 42849 | ZIP 14445 | +52.4 slots | 0–5 +52.4
#   Fac 242036 | ZIP 14445 | +1.6 slots | 0–5 +1.6
#   Fac 39760 | ZIP 14450 | +36.0 slots | 0–5 +36.0
#   Fac 39761 | ZIP 14450 | +25.8 slots | 0–5 +25.8
#   Fac 39762 | ZIP 14450 | +13.5 slots | 0–5 +13.5
#   Fac 40941 | ZIP 14450 | +7.3 slots | 0–5 +7.3
#   Fac 203448 | ZIP 14450 | +14.4 slots | 0–5 +14.4
#   Fac 299068 | ZIP 14450 | +14.1 slots | 0–5 +14.1
#   Fac 348495 | ZIP 14450 | +24.6 slots | 0–5 +24.6
#   Fac 600978 | ZIP 14450 | +8.8 slots | 0–5 +8.8
#   Fac 803420 | ZIP 14450 | +7.9 slots | 0–5 +7.9
#   Fac 884619 | ZIP 14450 | +7.3 slots | 0–5 +7.3
#   Fac 40051 | ZIP 14456 | +21.8 slots | 0–5 +21.8
#   Fac 43220 | ZIP 14456 | +16.1 slots | 0–5 +16.1
#   Fac 43467 | ZIP 14456 | +16.9 slots | 0–5 +16.9
#   Fac 251646 | ZIP 14456 | +7.0 slots | 0–5 +7.0
#   Fac 565116 | ZIP 14456 | +36.0 slots | 0–5 +36.0
#   Fac 795704 | ZIP 14456 | +12.6 slots | 0–5 +12.6
#   Fac 860513 | ZIP 14456 | +10.5 slots | 0–5 +10.5
#   Fac 227406 | ZIP 14470 | +14.2 slots | 0–5 +14.2
#   Fac 900067 | ZIP 14470 | +2.4 slots | 0–5 +2.4
#   Fac 848052 | ZIP 14476 | +18.7 slots | 0–5 +18.7
#   Fac 503506 | ZIP 14510 | +35.1 slots | 0–5 +0.0
#   Fac 904282 | ZIP 14510 | +6.9 slots | 0–5 +0.0
#   Fac 721458 | ZIP 14525 | +2.4 slots | 0–5 +2.4
#   Fac 766320 | ZIP 14525 | +2.5 slots | 0–5 +2.5
#   Fac 832636 | ZIP 14525 | +11.8 slots | 0–5 +11.8
#   Fac 406334 | ZIP 14526 | +5.3 slots | 0–5 +5.3
#   Fac 40042 | ZIP 14564 | +6.5 slots | 0–5 +6.5
#   Fac 594817 | ZIP 14564 | +17.5 slots | 0–5 +17.5
#   Fac 848065 | ZIP 14569 | +9.0 slots | 0–5 +9.0
#   Fac 873558 | ZIP 14569 | +5.0 slots | 0–5 +5.0
#   Fac 44403 | ZIP 14580 | +11.1 slots | 0–5 +11.1
#   Fac 272728 | ZIP 14580 | +24.3 slots | 0–5 +24.3
#   Fac 305733 | ZIP 14580 | +21.5 slots | 0–5 +21.5
#   Fac 560404 | ZIP 14580 | +11.2 slots | 0–5 +11.2
#   Fac 751100 | ZIP 14580 | +14.2 slots | 0–5 +14.2
#   Fac 752032 | ZIP 14580 | +14.4 slots | 0–5 +14.4
#   Fac 41635 | ZIP 14612 | +7.3 slots | 0–5 +7.3
#   Fac 44002 | ZIP 14621 | +6.7 slots | 0–5 +6.7
#   Fac 44698 | ZIP 14621 | +22.1 slots | 0–5 +22.1
#   Fac 714388 | ZIP 14621 | +13.5 slots | 0–5 +13.5
#   Fac 39768 | ZIP 14622 | +6.7 slots | 0–5 +6.7
#   Fac 39731 | ZIP 14625 | +15.5 slots | 0–5 +15.5
#   Fac 40945 | ZIP 14625 | +28.2 slots | 0–5 +28.2
#   Fac 42583 | ZIP 14625 | +32.0 slots | 0–5 +32.0
#   Fac 177729 | ZIP 14731 | +5.1 slots | 0–5 +5.1
#   Fac 547326 | ZIP 14731 | +6.6 slots | 0–5 +6.6
#   Fac 115279 | ZIP 14770 | +2.3 slots | 0–5 +2.3
#   Fac 877993 | ZIP 14774 | +10.0 slots | 0–5 +10.0
#
# --- Totals ---
#   New facilities: 4063 | Total new capacity: 1409100 | New 0–5 slots: 669075.2
#   Expanded facilities: 2086 | Total expansion: 35765.2 | 0–5 from expansion: 35221.8
# -------------------------------
